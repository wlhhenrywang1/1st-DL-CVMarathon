# %% [markdown]
# ## 『本次練習內容』
# #### 學習如何搭建 Residual Block
# ####  學習如何搭建Inception-ResNet中的 Inception Block

# %% [markdown]
# ## 『本次練習目的』
#   #### 了解 Residual Block原理
#   #### 了解如何結合Inception 與 Residual概念

# %% [markdown]
# ---

# %% [markdown]
# ## Part1

# %%
import numpy as np
from keras.models import Model
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras import backend as K
from keras import layers
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Lambda
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ![Incpeiton](ResNet_Structure.png)

# %% [markdown]
# ## ResNetV1

# %%
def Residual_block(input_tensor, kernel_size, filters, stage, block):
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
   

    x = layers.add([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %% [markdown]
# ## 參考ResNetV1 搭建 ResNetV2版本的Residual Block

# %%
def Residual_block_v2(input_tensor, kernel_size, filters, stage, block):
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = BatchNormalization(axis=3, name=bn_name_base + '2a')(input_tensor)
    x = Activation('relu')(x)
    x = Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(x)
    
    
    x = BatchNormalization(axis=3, name=bn_name_base + '2b')(x)   
    x = Activation('relu')(x)
    x = Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)

    x = layers.add([x, input_tensor])
    
    return x

# %% [markdown]
# ## 試試看自己設計一個先壓縮再回放的V2 Block

# %%
def Residual_block_v2(input_tensor, kernel_size, stage, block,reduce=64,ouput_size=128):
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    x = Conv2D(reduce, (1, 1), name=conv_name_base + '2a')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2a')(input_tensor)
    x = Activation('relu')(x)
    
    x = Conv2D(ouput_size, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv2D(ouput_size, (1, 1), name=conv_name_base + '2c')(x)
    
    x = layers.add([x, input_tensor])
    return x

# %% [markdown]
# ---

# %% [markdown]
# ## Part2

# %% [markdown]
# ## Incpetion Block-A

# %% [markdown]
# ![Incpeiton](Inception-ResNet-A.png)

# %% [markdown]
# ## Incpetion Block-B

# %% [markdown]
# ![Incpeiton](Inception-ResNet-B.png)

# %% [markdown]
# ## Incpetion Block-C

# %% [markdown]
# ![Incpeiton](Inception-ResNet-C.png)

# %%
def Conv2d_bn(x,filters,kernel_size,padding='same',strides=(1, 1),normalizer=True,activation='relu',name=None):
    if name is not None:
        conv_name = name + '_conv'
        bn_name = name + '_bn'
        act_name = name + '_act'
    else:
        conv_name = None
        bn_name = None
        act_name = None
    if K.image_data_format() == 'channels_first':
        bn_axis = 1
    else:
        bn_axis = 3
    x = Conv2D(filters, kernel_size,
               strides=strides, padding=padding,
               use_bias=False, name=conv_name)(x)
    if normalizer:
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    if activation:
        x = Activation(activation, name=act_name)(x)
    return x

# %%
def Residual_block(input_tensor, kernel_size, filters, stage, block):
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    x = layers.add([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %% [markdown]
# ## 參考上方Residual_block搭建 Inception-ResNet中的Inception Block

# %%
def inception_resnet_block(x, scale, block_type, activation='relu'):
    '''scale: scaling factor to scale the residuals (i.e., the output of
            passing `x` through an inception module) before adding them
            to the shortcut branch. Let `r` be the output from the residual branch,
            the output of this block will be `x + scale * r`.(簡單來說就是控制Residual branch的比例)'''
    if block_type == 'Incpetion_Block-A':
        branch_0 = Conv2d_bn(x,32,(1,1),name=block_type+'_Branch_0')
        branch_1 = Conv2d_bn(x,32,(1,1),name=block_type+'_Branch_1-1')
        branch_1 = Conv2d_bn(branch_1,32,(3,3),name=block_type+'_Branch_1-2')
        branch_2 = Conv2d_bn(x,32,(1,1),name=block_type+'_Branch_2-1')
        branch_2 = Conv2d_bn(branch_2,48,(3,3),name=block_type+'_Branch_2-2')
        branch_2 = Conv2d_bn(branch_2,64,(3,1),name=block_type+'_Branch_2-3')
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Incpetion_Block-B':
        branch_0 = Conv2d_bn(x,192,(1,1),name=block_type+'_Branch_0')
        branch_1 = Conv2d_bn(x,128,(1,1),name=block_type+'_Branch_1-1')
        branch_1 = Conv2d_bn(branch_1,160,(1,7),name=block_type+'_Branch_1-2')
        branch_1 = Conv2d_bn(branch_1,192,(7,1),name=block_type+'_Branch_1-3')
        branches = [branch_0, branch_1]
    elif block_type == 'Incpetion_Block-C':
        branch_0 = Conv2d_bn(x,192,(1,1),name=block_type+'_Branch_0')
        branch_1 = Conv2d_bn(x,192,(1,1),name=block_type+'_Branch_1-1')
        branch_1 = Conv2d_bn(branch_1,224,(1,3),name=block_type+'_Branch_1-2')
        branch_1 = Conv2d_bn(branch_1,256,(3,1),name=block_type+'_Branch_1-3')
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: ' + str(block_type))
    mixed = Concatenate(axis=3)(branches)
    
    '''確保輸入跟輸出深度相同'''
    up = Conv2d_bn(mixed,K.int_shape(x)[3],1,activation=None)
    
    '''導入殘差結構，並給予權重'''
    
    x = Lambda(lambda inputs, scale: inputs[0] + inputs[1] * scale, ##提示inputs[0]、inputs[1]
               output_shape=K.int_shape(x)[1:],
               arguments={'scale': scale},)([x,up])

    if activation is not None:
        x = Activation(activation)(x)
    return x

# %%
img_input = Input(shape=(224,224,32))
x=inception_resnet_block(img_input, 0.1, 'Incpetion_Block-A', activation='relu')
print(x)
# Out:
# Tensor("activation_1/Relu:0", shape=(None, 224, 224, 32), dtype=float32)

# %% [markdown]
# ## 測試

# %%
img_input = Input(shape=(224,224,32))
x=inception_resnet_block(img_input, 0.1, 'Incpetion_Block-A', activation='relu')
print(x)
# Out:
# Tensor("activation_2/Relu:0", shape=(None, 224, 224, 32), dtype=float32)

# %%
img_input = Input(shape=(224,224,32))
x=inception_resnet_block(img_input, 0.1, 'Incpetion_Block-B', activation='relu')
print(x)
# Out:
# Tensor("activation_3/Relu:0", shape=(None, 224, 224, 32), dtype=float32)

# %%
img_input = Input(shape=(224,224,32))
x=inception_resnet_block(img_input, 0.1, 'Incpetion_Block-C', activation='relu')
print(x)
# Out:
# Tensor("activation_4/Relu:0", shape=(None, 224, 224, 32), dtype=float32)

# %% [markdown]
# ## 嘗試導入Inception Block到 Vgg_Inception中

# %%
def VGG16_ResNet_Inception(include_top=True,input_tensor=None, input_shape=(224,224,1),
          pooling='max',classes=1000):
 
    img_input = Input(shape=input_shape)
    
    x = Conv2d_bn(img_input,64, (3, 3), activation='relu', padding='same', name='block1_conv1')
    x = Conv2d_bn(x,64, (3, 3), activation='relu', padding='same', name='block1_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2d_bn(x,128, (3, 3), activation='relu', padding='same', name='block2_conv1')
    x = Conv2d_bn(x,128, (3, 3), activation='relu', padding='same', name='block2_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, 'Block_1')
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, 'Block_2')
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, 'Block_3')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = inception_resnet_block(x, 0.1, 'Incpetion_Block-A', activation='relu')
    x = inception_resnet_block(x, 0.1, 'Incpetion_Block-B', activation='relu')
    x = inception_resnet_block(x, 0.1, 'Incpetion_Block-C', activation='relu')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5 
    #為什麼要加InceptionV3_block 原因?
    x =InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, 'Block_5-1')
    x =InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, 'Block_5-2')
    x =InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, 'Block_5-3')
    x =MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if include_top:
        # Classification block
        x = Flatten(name='flatten')(x)
        x = Dense(4096, activation='relu', name='fc1')(x)
        x = Dense(4096, activation='relu', name='fc2')(x)
        x = Dense(classes, activation='softmax', name='predictions')(x)
    else:
       #可以提醒學員為什麼要加avg或是max
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    inputs = img_input
    # Create model.
    model = Model(inputs, x, name='vgg16')

   
    return model

# %%
def InceptionV1_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 3), name=name+"_Branch_1_1")

    '''Branch_2'''
    branch_2 = Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2 = Conv2d_bn(branch_2, br2[1], (5, 5), name=name+"_Branch_2_1")

    '''Branch_3'''
    branch_3 = MaxPooling2D(pool_size=3, strides=1, padding='same')(x)
    branch_3 = Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3")
    

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# %%
def InceptionV3_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (1, 3), name=name+"_Branch_1_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 1), name=name+"_Branch_1_2")

    '''Branch_2'''
    branch_2 = Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2 = Conv2d_bn(branch_2, br2[1], (1, 5), name=name+"_Branch_2_1")
    branch_2 = Conv2d_bn(branch_2, br2[1], (5, 1), name=name+"_Branch_2_2")

    '''Branch_3'''
    branch_3 = MaxPooling2D(pool_size=3, strides=1, padding='same')(x)
    branch_3 = Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3")

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# %%
model = VGG16_ResNet_Inception(include_top=False)

# %%
model.summary()
# Out:
# Model: "vgg16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 224, 224, 1)  0
# __________________________________________________________________________________________________
# block1_conv1_conv (Conv2D)      (None, 224, 224, 64) 576         input_5[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 224, 224, 64) 192         block1_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 224, 224, 64) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_conv (Conv2D)      (None, 224, 224, 64) 36864       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 224, 224, 64) 192         block1_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 224, 224, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_conv (Conv2D)      (None, 112, 112, 128 73728       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 112, 112, 128 384         block2_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (Activation)   (None, 112, 112, 128 0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_conv (Conv2D)      (None, 112, 112, 128 147456      block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 112, 112, 128 384         block2_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (Activation)   (None, 112, 112, 128 0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_conv (Conv2D)  (None, 56, 56, 96)   12288       block2_pool[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_conv (Conv2D)  (None, 56, 56, 16)   2048        block2_pool[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_bn (BatchNorma (None, 56, 56, 96)   288         Block_1_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_bn (BatchNorma (None, 56, 56, 16)   48          Block_1_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_act (Activatio (None, 56, 56, 96)   0           Block_1_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_act (Activatio (None, 56, 56, 16)   0           Block_1_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           block2_pool[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_0_conv (Conv2D)  (None, 56, 56, 64)   8192        block2_pool[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_1_conv (Conv2D (None, 56, 56, 128)  110592      Block_1_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_1_conv (Conv2D (None, 56, 56, 32)   12800       Block_1_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_3_conv (Conv2D)  (None, 56, 56, 32)   4096        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_0_bn (BatchNorma (None, 56, 56, 64)   192         Block_1_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_1_bn (BatchNor (None, 56, 56, 128)  384         Block_1_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_1_bn (BatchNor (None, 56, 56, 32)   96          Block_1_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_3_bn (BatchNorma (None, 56, 56, 32)   96          Block_1_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_0_act (Activatio (None, 56, 56, 64)   0           Block_1_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_1_1_act (Activat (None, 56, 56, 128)  0           Block_1_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_2_1_act (Activat (None, 56, 56, 32)   0           Block_1_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_1_Branch_3_act (Activatio (None, 56, 56, 32)   0           Block_1_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_1_Concatenated (Concatena (None, 56, 56, 256)  0           Block_1_Branch_0_act[0][0]
#                                                                  Block_1_Branch_1_1_act[0][0]
#                                                                  Block_1_Branch_2_1_act[0][0]
#                                                                  Block_1_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_conv (Conv2D)  (None, 56, 56, 96)   24576       Block_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_conv (Conv2D)  (None, 56, 56, 16)   4096        Block_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_bn (BatchNorma (None, 56, 56, 96)   288         Block_2_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_bn (BatchNorma (None, 56, 56, 16)   48          Block_2_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_act (Activatio (None, 56, 56, 96)   0           Block_2_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_act (Activatio (None, 56, 56, 16)   0           Block_2_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 256)  0           Block_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_0_conv (Conv2D)  (None, 56, 56, 64)   16384       Block_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_1_conv (Conv2D (None, 56, 56, 128)  110592      Block_2_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_1_conv (Conv2D (None, 56, 56, 32)   12800       Block_2_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_3_conv (Conv2D)  (None, 56, 56, 32)   8192        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_0_bn (BatchNorma (None, 56, 56, 64)   192         Block_2_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_1_bn (BatchNor (None, 56, 56, 128)  384         Block_2_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_1_bn (BatchNor (None, 56, 56, 32)   96          Block_2_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_3_bn (BatchNorma (None, 56, 56, 32)   96          Block_2_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_0_act (Activatio (None, 56, 56, 64)   0           Block_2_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_1_1_act (Activat (None, 56, 56, 128)  0           Block_2_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_2_1_act (Activat (None, 56, 56, 32)   0           Block_2_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_2_Branch_3_act (Activatio (None, 56, 56, 32)   0           Block_2_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_2_Concatenated (Concatena (None, 56, 56, 256)  0           Block_2_Branch_0_act[0][0]
#                                                                  Block_2_Branch_1_1_act[0][0]
#                                                                  Block_2_Branch_2_1_act[0][0]
#                                                                  Block_2_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_conv (Conv2D)  (None, 56, 56, 96)   24576       Block_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_conv (Conv2D)  (None, 56, 56, 16)   4096        Block_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_bn (BatchNorma (None, 56, 56, 96)   288         Block_3_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_bn (BatchNorma (None, 56, 56, 16)   48          Block_3_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_act (Activatio (None, 56, 56, 96)   0           Block_3_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_act (Activatio (None, 56, 56, 16)   0           Block_3_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 56, 56, 256)  0           Block_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_0_conv (Conv2D)  (None, 56, 56, 64)   16384       Block_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_1_conv (Conv2D (None, 56, 56, 128)  110592      Block_3_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_1_conv (Conv2D (None, 56, 56, 32)   12800       Block_3_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_3_conv (Conv2D)  (None, 56, 56, 32)   8192        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_0_bn (BatchNorma (None, 56, 56, 64)   192         Block_3_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_1_bn (BatchNor (None, 56, 56, 128)  384         Block_3_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_1_bn (BatchNor (None, 56, 56, 32)   96          Block_3_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_3_bn (BatchNorma (None, 56, 56, 32)   96          Block_3_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_0_act (Activatio (None, 56, 56, 64)   0           Block_3_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_1_1_act (Activat (None, 56, 56, 128)  0           Block_3_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_2_1_act (Activat (None, 56, 56, 32)   0           Block_3_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_3_act (Activatio (None, 56, 56, 32)   0           Block_3_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Concatenated (Concatena (None, 56, 56, 256)  0           Block_3_Branch_0_act[0][0]
#                                                                  Block_3_Branch_1_1_act[0][0]
#                                                                  Block_3_Branch_2_1_act[0][0]
#                                                                  Block_3_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           Block_3_Concatenated[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-1_co (None, 28, 28, 32)   8192        block3_pool[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-1_bn (None, 28, 28, 32)   96          Incpetion_Block-A_Branch_2-1_conv
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-1_ac (None, 28, 28, 32)   0           Incpetion_Block-A_Branch_2-1_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-1_co (None, 28, 28, 32)   8192        block3_pool[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-2_co (None, 28, 28, 48)   13824       Incpetion_Block-A_Branch_2-1_act[
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-1_bn (None, 28, 28, 32)   96          Incpetion_Block-A_Branch_1-1_conv
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-2_bn (None, 28, 28, 48)   144         Incpetion_Block-A_Branch_2-2_conv
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-1_ac (None, 28, 28, 32)   0           Incpetion_Block-A_Branch_1-1_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-2_ac (None, 28, 28, 48)   0           Incpetion_Block-A_Branch_2-2_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_0_conv (None, 28, 28, 32)   8192        block3_pool[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-2_co (None, 28, 28, 32)   9216        Incpetion_Block-A_Branch_1-1_act[
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-3_co (None, 28, 28, 64)   9216        Incpetion_Block-A_Branch_2-2_act[
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_0_bn ( (None, 28, 28, 32)   96          Incpetion_Block-A_Branch_0_conv[0
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-2_bn (None, 28, 28, 32)   96          Incpetion_Block-A_Branch_1-2_conv
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-3_bn (None, 28, 28, 64)   192         Incpetion_Block-A_Branch_2-3_conv
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_0_act  (None, 28, 28, 32)   0           Incpetion_Block-A_Branch_0_bn[0][
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_1-2_ac (None, 28, 28, 32)   0           Incpetion_Block-A_Branch_1-2_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-A_Branch_2-3_ac (None, 28, 28, 64)   0           Incpetion_Block-A_Branch_2-3_bn[0
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 128)  0           Incpetion_Block-A_Branch_0_act[0]
#                                                                  Incpetion_Block-A_Branch_1-2_act[
#                                                                  Incpetion_Block-A_Branch_2-3_act[
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 256)  32768       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 256)  768         conv2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 28, 28, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 256)  0           lambda_5[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-1_co (None, 28, 28, 128)  32768       activation_5[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-1_bn (None, 28, 28, 128)  384         Incpetion_Block-B_Branch_1-1_conv
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-1_ac (None, 28, 28, 128)  0           Incpetion_Block-B_Branch_1-1_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-2_co (None, 28, 28, 160)  143360      Incpetion_Block-B_Branch_1-1_act[
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-2_bn (None, 28, 28, 160)  480         Incpetion_Block-B_Branch_1-2_conv
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-2_ac (None, 28, 28, 160)  0           Incpetion_Block-B_Branch_1-2_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_0_conv (None, 28, 28, 192)  49152       activation_5[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-3_co (None, 28, 28, 192)  215040      Incpetion_Block-B_Branch_1-2_act[
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_0_bn ( (None, 28, 28, 192)  576         Incpetion_Block-B_Branch_0_conv[0
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-3_bn (None, 28, 28, 192)  576         Incpetion_Block-B_Branch_1-3_conv
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_0_act  (None, 28, 28, 192)  0           Incpetion_Block-B_Branch_0_bn[0][
# __________________________________________________________________________________________________
# Incpetion_Block-B_Branch_1-3_ac (None, 28, 28, 192)  0           Incpetion_Block-B_Branch_1-3_bn[0
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 384)  0           Incpetion_Block-B_Branch_0_act[0]
#                                                                  Incpetion_Block-B_Branch_1-3_act[
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 256)  98304       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 256)  768         conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 28, 28, 256)  0           activation_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 256)  0           lambda_6[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-1_co (None, 28, 28, 192)  49152       activation_6[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-1_bn (None, 28, 28, 192)  576         Incpetion_Block-C_Branch_1-1_conv
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-1_ac (None, 28, 28, 192)  0           Incpetion_Block-C_Branch_1-1_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-2_co (None, 28, 28, 224)  129024      Incpetion_Block-C_Branch_1-1_act[
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-2_bn (None, 28, 28, 224)  672         Incpetion_Block-C_Branch_1-2_conv
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-2_ac (None, 28, 28, 224)  0           Incpetion_Block-C_Branch_1-2_bn[0
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_0_conv (None, 28, 28, 192)  49152       activation_6[0][0]
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-3_co (None, 28, 28, 256)  172032      Incpetion_Block-C_Branch_1-2_act[
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_0_bn ( (None, 28, 28, 192)  576         Incpetion_Block-C_Branch_0_conv[0
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-3_bn (None, 28, 28, 256)  768         Incpetion_Block-C_Branch_1-3_conv
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_0_act  (None, 28, 28, 192)  0           Incpetion_Block-C_Branch_0_bn[0][
# __________________________________________________________________________________________________
# Incpetion_Block-C_Branch_1-3_ac (None, 28, 28, 256)  0           Incpetion_Block-C_Branch_1-3_bn[0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 448)  0           Incpetion_Block-C_Branch_0_act[0]
#                                                                  Incpetion_Block-C_Branch_1-3_act[
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  114688      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  768         conv2d_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 28, 28, 256)  0           activation_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           lambda_7[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_conv (Conv2D (None, 14, 14, 192)  49152       block4_pool[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_conv (Conv2D (None, 14, 14, 32)   8192        block4_pool[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_bn (BatchNor (None, 14, 14, 192)  576         Block_5-1_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_bn (BatchNor (None, 14, 14, 32)   96          Block_5-1_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_act (Activat (None, 14, 14, 192)  0           Block_5-1_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_act (Activat (None, 14, 14, 32)   0           Block_5-1_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_1_conv (Conv (None, 14, 14, 256)  147456      Block_5-1_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_1_conv (Conv (None, 14, 14, 64)   10240       Block_5-1_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_1_bn (BatchN (None, 14, 14, 256)  768         Block_5-1_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_1_bn (BatchN (None, 14, 14, 64)   192         Block_5-1_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_1_act (Activ (None, 14, 14, 256)  0           Block_5-1_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_1_act (Activ (None, 14, 14, 64)   0           Block_5-1_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 256)  0           block4_pool[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_0_conv (Conv2D (None, 14, 14, 128)  32768       block4_pool[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_2_conv (Conv (None, 14, 14, 256)  196608      Block_5-1_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_2_conv (Conv (None, 14, 14, 64)   20480       Block_5-1_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_3_conv (Conv2D (None, 14, 14, 64)   16384       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_0_bn (BatchNor (None, 14, 14, 128)  384         Block_5-1_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_2_bn (BatchN (None, 14, 14, 256)  768         Block_5-1_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_2_bn (BatchN (None, 14, 14, 64)   192         Block_5-1_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_3_bn (BatchNor (None, 14, 14, 64)   192         Block_5-1_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_0_act (Activat (None, 14, 14, 128)  0           Block_5-1_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_1_2_act (Activ (None, 14, 14, 256)  0           Block_5-1_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_2_2_act (Activ (None, 14, 14, 64)   0           Block_5-1_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Branch_3_act (Activat (None, 14, 14, 64)   0           Block_5-1_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-1_Concatenated (Concate (None, 14, 14, 512)  0           Block_5-1_Branch_0_act[0][0]
#                                                                  Block_5-1_Branch_1_2_act[0][0]
#                                                                  Block_5-1_Branch_2_2_act[0][0]
#                                                                  Block_5-1_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_conv (Conv2D (None, 14, 14, 192)  98304       Block_5-1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_conv (Conv2D (None, 14, 14, 32)   16384       Block_5-1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_bn (BatchNor (None, 14, 14, 192)  576         Block_5-2_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_bn (BatchNor (None, 14, 14, 32)   96          Block_5-2_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_act (Activat (None, 14, 14, 192)  0           Block_5-2_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_act (Activat (None, 14, 14, 32)   0           Block_5-2_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_1_conv (Conv (None, 14, 14, 256)  147456      Block_5-2_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_1_conv (Conv (None, 14, 14, 64)   10240       Block_5-2_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_1_bn (BatchN (None, 14, 14, 256)  768         Block_5-2_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_1_bn (BatchN (None, 14, 14, 64)   192         Block_5-2_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_1_act (Activ (None, 14, 14, 256)  0           Block_5-2_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_1_act (Activ (None, 14, 14, 64)   0           Block_5-2_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           Block_5-1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_0_conv (Conv2D (None, 14, 14, 128)  65536       Block_5-1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_2_conv (Conv (None, 14, 14, 256)  196608      Block_5-2_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_2_conv (Conv (None, 14, 14, 64)   20480       Block_5-2_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_3_conv (Conv2D (None, 14, 14, 64)   32768       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_0_bn (BatchNor (None, 14, 14, 128)  384         Block_5-2_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_2_bn (BatchN (None, 14, 14, 256)  768         Block_5-2_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_2_bn (BatchN (None, 14, 14, 64)   192         Block_5-2_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_3_bn (BatchNor (None, 14, 14, 64)   192         Block_5-2_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_0_act (Activat (None, 14, 14, 128)  0           Block_5-2_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_1_2_act (Activ (None, 14, 14, 256)  0           Block_5-2_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_2_2_act (Activ (None, 14, 14, 64)   0           Block_5-2_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Branch_3_act (Activat (None, 14, 14, 64)   0           Block_5-2_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-2_Concatenated (Concate (None, 14, 14, 512)  0           Block_5-2_Branch_0_act[0][0]
#                                                                  Block_5-2_Branch_1_2_act[0][0]
#                                                                  Block_5-2_Branch_2_2_act[0][0]
#                                                                  Block_5-2_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_conv (Conv2D (None, 14, 14, 192)  98304       Block_5-2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_conv (Conv2D (None, 14, 14, 32)   16384       Block_5-2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_bn (BatchNor (None, 14, 14, 192)  576         Block_5-3_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_bn (BatchNor (None, 14, 14, 32)   96          Block_5-3_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_act (Activat (None, 14, 14, 192)  0           Block_5-3_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_act (Activat (None, 14, 14, 32)   0           Block_5-3_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_1_conv (Conv (None, 14, 14, 256)  147456      Block_5-3_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_1_conv (Conv (None, 14, 14, 64)   10240       Block_5-3_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_1_bn (BatchN (None, 14, 14, 256)  768         Block_5-3_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_1_bn (BatchN (None, 14, 14, 64)   192         Block_5-3_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_1_act (Activ (None, 14, 14, 256)  0           Block_5-3_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_1_act (Activ (None, 14, 14, 64)   0           Block_5-3_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           Block_5-2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_0_conv (Conv2D (None, 14, 14, 128)  65536       Block_5-2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_2_conv (Conv (None, 14, 14, 256)  196608      Block_5-3_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_2_conv (Conv (None, 14, 14, 64)   20480       Block_5-3_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_3_conv (Conv2D (None, 14, 14, 64)   32768       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_0_bn (BatchNor (None, 14, 14, 128)  384         Block_5-3_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_2_bn (BatchN (None, 14, 14, 256)  768         Block_5-3_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_2_bn (BatchN (None, 14, 14, 64)   192         Block_5-3_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_3_bn (BatchNor (None, 14, 14, 64)   192         Block_5-3_Branch_3_conv[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_0_act (Activat (None, 14, 14, 128)  0           Block_5-3_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_1_2_act (Activ (None, 14, 14, 256)  0           Block_5-3_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_2_2_act (Activ (None, 14, 14, 64)   0           Block_5-3_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Branch_3_act (Activat (None, 14, 14, 64)   0           Block_5-3_Branch_3_bn[0][0]
# __________________________________________________________________________________________________
# Block_5-3_Concatenated (Concate (None, 14, 14, 512)  0           Block_5-3_Branch_0_act[0][0]
#                                                                  Block_5-3_Branch_1_2_act[0][0]
#                                                                  Block_5-3_Branch_2_2_act[0][0]
#                                                                  Block_5-3_Branch_3_act[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           Block_5-3_Concatenated[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 512)          0           block5_pool[0][0]
# ==================================================================================================
# Total params: 3,582,624
# Trainable params: 3,568,224
# Non-trainable params: 14,400
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='VGG16_ResNet_Inception.png', show_shapes=True, show_layer_names=True)
